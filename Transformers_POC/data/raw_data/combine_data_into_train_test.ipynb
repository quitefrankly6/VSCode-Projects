# %%
import pandas as pd 
import numpy as np
from pathlib import Path

# %%
directory_path = Path('.') # Create a Path object

# List all files in the directory (non-recursive)
file_list_pathlib = [str(file) for file in directory_path.iterdir() if file.is_file() and '.csv' in str(file) and 'hard_rent_classification_10000.csv' not in str(file)]

print(file_list_pathlib)
# Out:
# ['Checking1.csv', 'frank_labeled_data.csv']

# %%
df_dict  = {}

for file in file_list_pathlib:
    try:
        # Read the file and use the filename as the dictionary key
        df = pd.read_csv(file)
        # os.path.basename(file) gets just the filename without the full path
        df_dict[os.path.basename(file)] = df
        print(f"Successfully read {file}")
    except Exception as e:
        print(f"Error reading {file}: {e}")
# Out:
# Successfully read Checking1.csv
# Successfully read frank_labeled_data.csv

# %%
cols_to_select = ['Description', 'Rent']

# %%
selected_dfs = []

# %%
selected_dfs.append(df_dict['Checking1.csv'][cols_to_select])

# %%
selected_dfs.append(df_dict['frank_labeled_data.csv'].rename(columns = {'rent':'Rent'})[cols_to_select])

# %%
selected_dfs
# Out:
# [                                           Description  Rent
#  0           WF Credit Card AUTO PAY 260102 OOOOO OOOOO     0
#  1           WF Credit Card AUTO PAY 260101 OOOOO OOOOO     0
#  2    ZELLE FROM OOOOO ON 12/26 REF # COF2H8DF53VH K...     0
#  3    FEDERAL NATIONAL PAYROLL 251226 939238644926DV...     0
#  4               BENEFIT PAYMENT EDI PYMNTS OOOOO OOOOO     0
#  ..                                                 ...   ...
#  143            ZELLE TO OOOOO ON 07/28 REF #PP0XXPHGQ5     0
#  144  ZELLE TO OOOOO ON 07/27 REF #RP0XXMW95D GUITAR...     0
#  145  FANNIE MAE DIRECT DEP 240726 595067835251P22 O...     0
#  146           BOARD OF REGENTS Georgia Te 071724 OOOOO     0
#  147  ZELLE FROM OOOOO ON 07/14 REF # PP0SF7ZS5M AUT...     0
#
#  [148 rows x 2 columns],
#                                         Description  Rent
#  0                          ZEL ZELLE TO LIU BAOZHU     1
#  1                 ECK VENMO 3264681992  BR PAYMENT     0
#  2                              INT INTEREST CREDIT     0
#  3                 ECK VENMO 3264681992  BR PAYMENT     0
#  4      DIR FEDERAL NATIONAL 9111111101  BR PAYROLL     0
#  ..                                             ...   ...
#  349                            INT INTEREST CREDIT     0
#  350  ECK CITIZE CK WEBXFR 3770527921  BR ETRANSFER     0
#  351       DIR FANNIE MAE 9111111101  BR DIRECT DEP     0
#  352         ECK Subscription 9000142694  BR Acorns     0
#  353        ECK CITI AUTOPAY CITICARDAP  BR PAYMENT     0
#
#  [354 rows x 2 columns]]

# %%
# Combine all DataFrames into a single one
if selected_dfs:
    combined_df = pd.concat(selected_dfs, ignore_index=True)
    print("\nSuccessfully combined all files into a single DataFrame.")
    print(f"Total combined shape: {combined_df.shape}")
    # print the first few rows of the combined dataframe
    print(combined_df.head()) 
else:
    print("No dataframes were successfully loaded to combine.")
# Out:
# Successfully combined all files into a single DataFrame.
# Total combined shape: (502, 2)
#                                          Description  Rent
# 0         WF Credit Card AUTO PAY 260102 OOOOO OOOOO     0
# 1         WF Credit Card AUTO PAY 260101 OOOOO OOOOO     0
# 2  ZELLE FROM OOOOO ON 12/26 REF # COF2H8DF53VH K...     0
# 3  FEDERAL NATIONAL PAYROLL 251226 939238644926DV...     0
# 4             BENEFIT PAYMENT EDI PYMNTS OOOOO OOOOO     0

# %%
combined_df.value_counts('Rent')
# Out:
# Rent
# 0    476
# 1     26
# Name: count, dtype: int64

# %%
combined_df.to_csv('../processed_data/combined_df.csv')

# %%
hard_test_set = pd.read_csv('../raw_data/hard_rent_classification_10000.csv')

hard_test_set.rename(columns={'rent':'Rent'}, inplace=True)

# %%
hard_test_set_filtered = hard_test_set[cols_to_select]

# %%
hard_test_set_filtered.to_csv('../processed_data/hard_test_set.csv')
